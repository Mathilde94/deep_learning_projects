# %%
import os
import sys
import time

from data.constants import saved_sessions_root
from data.generate import build
from data.load import (get_testing_set, get_training_set, get_validation_set,
                       load_sets_from_file)
from data.text_load import build as text_build
from models.models import ConvolutionNeuralNetwork, LogisticRegression, NeuralNetwork, Word2Vec
from classifier.helpers import show_stats_from_file
from classifier.models import Classifier, TextClassifier
from model_trainer.models import DataForTrainer, DataSet

# %%
data, reverse_dictionary = text_build()
model = Word2Vec()
classifier = TextClassifier(model)
classifier.train(data, reverse_dictionary)
# Out:
# Found and verified text8.zip
# data sample: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# Average loss at step 0: 8.153477
# Nearest to however: greenblatt, alignment, narita, rabbit, skilling, nihonshoki, natively, pbk,
# Nearest to its: pots, vocative, smooth, selamat, hiss, miscegenation, interludes, bashing,
# Nearest to UNK: seminal, bakery, conti, cooling, foreigner, camra, musketeers, axis,
# Nearest to up: facet, immunization, carleton, interested, needed, kirkpatrick, utilized, koenigsegg,
# Nearest to on: slices, madre, mimic, sharpening, ramanujan, optics, sluggish, accelerates,
# Nearest to these: sulfide, sos, oxygen, shit, natalia, electoral, guarani, christiaan,
# Nearest to one: functionaries, pointing, molly, foliage, png, microseconds, volcano, aykroyd,
# Nearest to all: admirable, sticking, inquisitor, fearful, william, successive, gregorian, neutronic,
# Nearest to was: midwestern, disloyalty, sulpicius, cults, shouts, puritan, navigators, ruud,
# Nearest to th: serpent, migrant, uke, extensive, valentinians, budgets, subunit, horribly,
# Nearest to first: bodyguards, surprisingly, federko, hg, familiarity, informative, rockefeller, mifflin,
# Nearest to are: garc, battlefield, disperse, hyped, petitioner, pulsed, confining, songwriters,
# Nearest to also: asbestos, curator, delimitation, acc, tuberculosis, clover, beheaded, empanadas,
# Nearest to an: casanova, organizing, gametes, piccard, earthman, despair, imbued, magnet,
# Nearest to many: resistive, grenadines, condemns, adolphe, dragonball, branko, niger, saucer,
# Nearest to often: means, antitank, passy, starting, battleship, mervyn, culmination, ligases,
# Average loss at step 2000: 5.694491
# Average loss at step 4000: 4.725733
# Average loss at step 6000: 4.545751
# Average loss at step 8000: 4.329084
# Average loss at step 10000: 4.182738
# Nearest to however: greenblatt, skilling, nihonshoki, alignment, cotswolds, natively, rabbit, narita,
# Nearest to its: pots, vocative, smooth, selamat, bashing, sanctuaries, miscegenation, interludes,
# Nearest to UNK: is, the, camra, and, mosquitoes, bakery, seminal, four,
# Nearest to up: facet, immunization, carleton, utilized, kirkpatrick, needed, interested, raf,
# Nearest to on: with, optics, mimic, sports, making, bertrand, valentine, is,
# Nearest to these: sulfide, sos, oxygen, natalia, christiaan, electoral, shit, guarani,
# Nearest to one: molly, volcano, two, pointing, foliage, mansion, people, tart,
# Nearest to all: fearful, william, admirable, sticking, inquisitor, entirety, hatton, successive,
# Nearest to was: ruud, cults, disloyalty, nn, endpoints, tl, navigators, yyyy,
# Nearest to th: migrant, uke, skirt, rijndael, budgets, subunit, atomism, dejima,
# Nearest to first: surprisingly, bodyguards, hg, handler, pseudo, mifflin, familiarity, bjorn,
# Nearest to are: garc, yoke, confining, revue, pulsed, darkest, dimensions, steroid,
# Nearest to also: curator, acc, beheaded, asbestos, tuberculosis, instructed, street, episkopos,
# Nearest to an: is, piccard, organizing, gametes, bassists, casanova, survival, imbued,
# Nearest to many: condemns, grenadines, branko, resistive, niger, saucer, collectivity, interwiki,
# Nearest to often: antitank, means, passy, battleship, starting, seven, configure, avon,
# Average loss at step 12000: 4.132864
# Average loss at step 14000: 4.061899
# Average loss at step 16000: 3.859602
# Average loss at step 18000: 3.908194
# Average loss at step 20000: 4.014319
# Nearest to however: greenblatt, nihonshoki, cotswolds, skilling, natively, bison, rabbit, hymn,
# Nearest to its: vocative, smooth, selamat, sanctuaries, pots, bashing, engages, tocharians,
# Nearest to UNK: is, the, and, camra, four, mosquitoes, bakery, in,
# Nearest to up: facet, immunization, utilized, carleton, kirkpatrick, raf, needed, interested,
# Nearest to on: with, by, is, in, and, of, for, optics,
# Nearest to these: sulfide, christiaan, sos, electoral, natalia, oxygen, arid, guarani,
# Nearest to one: two, molly, people, and, the, poisons, tart, respects,
# Nearest to all: william, fearful, entirety, hatton, portfolio, admirable, sticking, topological,
# Nearest to was: is, were, and, ruud, endpoints, tl, nn, sur,
# Nearest to th: migrant, uke, skirt, rijndael, budgets, atomism, hydrogen, dejima,
# Nearest to first: surprisingly, handler, hg, bodyguards, pseudo, bjorn, pizzicato, kamenev,
# Nearest to are: is, yoke, garc, by, were, and, penile, revue,
# Nearest to also: curator, acc, asbestos, beheaded, tuberculosis, episkopos, street, tiu,
# Nearest to an: is, a, piccard, organizing, bassists, gametes, survival, rebranded,
# Nearest to many: branko, grenadines, condemns, the, niger, resistive, saucer, collectivity,
# Nearest to often: antitank, means, battleship, passy, starting, seven, lost, configure,
# Average loss at step 22000: 3.940716
# Average loss at step 24000: 3.925598
# Average loss at step 26000: 3.886932
# Average loss at step 28000: 3.851000
# Average loss at step 30000: 3.917682
# Nearest to however: greenblatt, cotswolds, nihonshoki, skilling, natively, bison, hymn, that,
# Nearest to its: the, vocative, smooth, sanctuaries, selamat, bashing, engages, tocharians,
# Nearest to UNK: is, the, and, camra, four, mosquitoes, bakery, one,
# Nearest to up: facet, immunization, utilized, raf, kirkpatrick, carleton, needed, modestly,
# Nearest to on: with, by, in, is, for, of, and, from,
# Nearest to these: their, sulfide, christiaan, electoral, but, arid, natalia, sos,
# Nearest to one: two, molly, people, the, four, five, and, respects,
# Nearest to all: william, fearful, portfolio, topological, entirety, newsgroup, uncollected, hatton,
# Nearest to was: is, were, and, tl, ruud, endpoints, relena, nn,
# Nearest to th: migrant, uke, skirt, rijndael, budgets, p, atomism, hydrogen,
# Nearest to first: handler, surprisingly, at, pseudo, hg, bodyguards, pizzicato, hollowed,
# Nearest to are: is, were, by, and, from, yoke, they, archons,
# Nearest to also: curator, acc, asbestos, beheaded, that, episkopos, street, tiu,
# Nearest to an: is, the, a, piccard, bassists, perturbed, organizing, gametes,
# Nearest to many: the, branko, condemns, grenadines, a, niger, avid, kamov,
# Nearest to often: antitank, battleship, starting, means, passy, lost, seven, clapton,
# Average loss at step 32000: 3.887901
# Average loss at step 34000: 3.888605
# Average loss at step 36000: 3.864961
# Average loss at step 38000: 3.757703
# Average loss at step 40000: 3.831925
# Nearest to however: greenblatt, that, cotswolds, nihonshoki, skilling, quincy, natively, bison,
# Nearest to its: the, his, this, smooth, sanctuaries, vocative, bashing, engages,
# Nearest to UNK: is, and, four, one, airforce, bakery, camra, mosquitoes,
# Nearest to up: facet, immunization, utilized, raf, modestly, kirkpatrick, needed, resigning,
# Nearest to on: with, in, by, for, from, is, and, of,
# Nearest to these: their, sulfide, christiaan, but, electoral, arid, other, ineffable,
# Nearest to one: two, five, molly, people, the, UNK, four, six,
# Nearest to all: fearful, william, portfolio, their, topological, uncollected, entirety, newsgroup,
# Nearest to was: is, were, tl, had, ruud, relena, endpoints, has,
# Nearest to th: migrant, uke, skirt, p, budgets, rijndael, atomism, hydrogen,
# Nearest to first: at, handler, pseudo, surprisingly, hollowed, enamoured, pizzicato, hg,
# Nearest to are: were, is, by, and, from, other, they, yoke,
# Nearest to also: curator, acc, that, asbestos, not, episkopos, street, beheaded,
# Nearest to an: the, a, is, piccard, perturbed, omnivores, bassists, french,
# Nearest to many: the, branko, a, condemns, grenadines, some, avid, their,
# Nearest to often: antitank, lost, battleship, starting, means, passy, system, seven,
# Average loss at step 42000: 3.804801
# Average loss at step 44000: 3.816081
# Average loss at step 46000: 3.805757
# Average loss at step 48000: 3.723094
# Average loss at step 50000: 3.738585
# Nearest to however: that, greenblatt, cotswolds, nihonshoki, quincy, skilling, also, natively,
# Nearest to its: the, his, this, smooth, sanctuaries, vocative, their, bashing,
# Nearest to UNK: four, one, is, airforce, bakery, mosquitoes, and, camra,
# Nearest to up: facet, immunization, raf, utilized, modestly, resigning, kirkpatrick, needed,
# Nearest to on: with, in, by, from, for, at, is, and,
# Nearest to these: their, sulfide, christiaan, other, but, electoral, many, arid,
# Nearest to one: two, five, four, six, molly, UNK, people, the,
# Nearest to all: fearful, their, william, portfolio, home, topological, uncollected, people,
# Nearest to was: is, were, had, has, tl, ruud, when, relena,
# Nearest to th: migrant, uke, skirt, budgets, rijndael, p, atomism, hydrogen,
# Nearest to first: at, handler, pseudo, surprisingly, hollowed, pizzicato, enamoured, exclaimed,
# Nearest to are: were, is, by, and, from, other, yoke, archons,
# Nearest to also: curator, acc, that, not, episkopos, asbestos, they, street,
# Nearest to an: the, piccard, a, perturbed, omnivores, imbued, gametes, brooms,
# Nearest to many: the, some, branko, their, condemns, a, these, grenadines,
# Nearest to often: antitank, lost, battleship, starting, system, means, grimm, passy,
# Average loss at step 52000: 3.769033
# Average loss at step 54000: 3.778506
# Average loss at step 56000: 3.761408
# Average loss at step 58000: 3.752301
# Average loss at step 60000: 3.774020
# Nearest to however: that, greenblatt, cotswolds, quincy, nihonshoki, also, skilling, sea,
# Nearest to its: the, his, this, their, smooth, sanctuaries, vocative, bashing,
# Nearest to UNK: four, airforce, is, one, seminal, secondary, bakery, mosquitoes,
# Nearest to up: facet, immunization, utilized, raf, modestly, resigning, kirkpatrick, needed,
# Nearest to on: with, in, by, from, for, at, is, sports,
# Nearest to these: their, sulfide, christiaan, other, many, electoral, but, arid,
# Nearest to one: two, five, four, six, people, molly, which, UNK,
# Nearest to all: their, fearful, portfolio, home, uncollected, topological, william, people,
# Nearest to was: is, were, had, has, tl, when, ruud, relena,
# Nearest to th: migrant, uke, p, skirt, budgets, rijndael, hakim, hydrogen,
# Nearest to first: at, handler, pseudo, pizzicato, hollowed, enamoured, surprisingly, within,
# Nearest to are: were, is, and, by, from, yoke, other, archons,
# Nearest to also: curator, acc, that, not, episkopos, they, asbestos, street,
# Nearest to an: the, piccard, imbued, perturbed, omnivores, gametes, brooms, a,
# Nearest to many: the, some, their, these, branko, off, condemns, a,
# Nearest to often: lost, antitank, starting, system, battleship, grimm, distortion, means,
# Average loss at step 62000: 3.660855
# Average loss at step 64000: 3.636615
# Average loss at step 66000: 3.759975
# Average loss at step 68000: 3.727810
# Average loss at step 70000: 3.702762
# Nearest to however: that, greenblatt, cotswolds, quincy, also, nihonshoki, sea, skilling,
# Nearest to its: the, his, their, this, some, smooth, sanctuaries, engages,
# Nearest to UNK: four, airforce, secondary, seminal, one, is, mosquitoes, salom,
# Nearest to up: facet, immunization, raf, utilized, modestly, resigning, needed, kirkpatrick,
# Nearest to on: with, in, by, from, at, for, sports, into,
# Nearest to these: their, many, other, sulfide, christiaan, such, some, electoral,
# Nearest to one: two, five, six, four, molly, headphones, people, three,
# Nearest to all: their, fearful, portfolio, uncollected, home, topological, people, newsgroup,
# Nearest to was: is, were, had, has, when, tl, relena, ruud,
# Nearest to th: migrant, billion, uke, budgets, skirt, p, rijndael, hakim,
# Nearest to first: at, handler, pseudo, within, city, enamoured, hollowed, pizzicato,
# Nearest to are: were, is, by, from, and, yoke, other, archons,
# Nearest to also: curator, acc, that, not, episkopos, however, they, asbestos,
# Nearest to an: the, piccard, imbued, perturbed, omnivores, brooms, gametes, alphabetically,
# Nearest to many: some, the, these, their, off, condemns, branko, its,
# Nearest to often: lost, system, starting, antitank, battleship, grimm, nilo, distortion,
# Average loss at step 72000: 3.707630
# Average loss at step 74000: 3.700610
# Average loss at step 76000: 3.703085
# Average loss at step 78000: 3.690754
# Average loss at step 80000: 3.693393
# Nearest to however: that, greenblatt, quincy, cotswolds, also, nihonshoki, sea, same,
# Nearest to its: the, his, their, this, some, smooth, many, sanctuaries,
# Nearest to UNK: secondary, airforce, four, axis, salom, bakery, mosquitoes, r,
# Nearest to up: facet, raf, utilized, immunization, modestly, resigning, needed, kirkpatrick,
# Nearest to on: with, in, by, from, at, for, sports, into,
# Nearest to these: their, many, sulfide, other, such, christiaan, some, arid,
# Nearest to one: two, five, six, four, molly, three, headphones, angelic,
# Nearest to all: fearful, their, portfolio, uncollected, home, topological, people, newsgroup,
# Nearest to was: is, were, had, has, tl, when, relena, ruud,
# Nearest to th: migrant, billion, uke, budgets, p, skirt, rijndael, hakim,
# Nearest to first: at, handler, within, pseudo, city, pizzicato, implicated, antiprotons,
# Nearest to are: were, is, by, have, from, yoke, archons, and,
# Nearest to also: curator, acc, not, that, episkopos, however, asbestos, they,
# Nearest to an: the, imbued, piccard, perturbed, omnivores, brooms, gametes, alphabetically,
# Nearest to many: some, the, these, their, off, condemns, congratulate, its,
# Nearest to often: lost, system, starting, grimm, nilo, vieux, antitank, battleship,
# Average loss at step 82000: 3.705904
# Average loss at step 84000: 3.713248
# Average loss at step 86000: 3.686250
# Average loss at step 88000: 3.670100
# Average loss at step 90000: 3.670572
# Nearest to however: that, greenblatt, quincy, also, cotswolds, sea, nihonshoki, same,
# Nearest to its: the, his, their, this, some, many, naturalism, whose,
# Nearest to UNK: airforce, four, secondary, r, axis, salom, bakery, one,
# Nearest to up: facet, raf, utilized, modestly, immunization, resigning, needed, kirkpatrick,
# Nearest to on: with, in, by, from, at, for, sports, into,
# Nearest to these: their, many, such, some, sulfide, other, christiaan, arid,
# Nearest to one: two, six, five, four, three, molly, headphones, respects,
# Nearest to all: their, uncollected, fearful, portfolio, home, topological, people, newsgroup,
# Nearest to was: is, were, had, has, tl, when, relena, ruud,
# Nearest to th: migrant, billion, p, uke, budgets, rijndael, skirt, hakim,
# Nearest to first: at, handler, within, pseudo, city, pizzicato, implicated, antiprotons,
# Nearest to are: were, is, have, by, yoke, archons, including, or,
# Nearest to also: curator, acc, not, that, episkopos, however, now, asbestos,
# Nearest to an: the, imbued, piccard, perturbed, omnivores, brooms, gametes, alphabetically,
# Nearest to many: some, these, the, their, each, off, congratulate, its,
# Nearest to often: lost, system, starting, grimm, nilo, vieux, changeover, distortion,
# Average loss at step 92000: 3.701362
# Average loss at step 94000: 3.590911
# Average loss at step 96000: 3.657525
# Average loss at step 98000: 3.575443
# Average loss at step 100000: 3.651106
# Nearest to however: that, greenblatt, quincy, cotswolds, also, sea, nihonshoki, same,
# Nearest to its: the, his, their, this, some, whose, many, naturalism,
# Nearest to UNK: airforce, four, secondary, r, salom, axis, bakery, journal,
# Nearest to up: facet, raf, modestly, utilized, immunization, needed, resigning, cem,
# Nearest to on: with, in, from, at, by, for, into, sports,
# Nearest to these: their, many, some, such, other, sulfide, christiaan, arid,
# Nearest to one: two, five, six, four, respects, three, vol, molly,
# Nearest to all: their, home, uncollected, portfolio, fearful, topological, people, each,
# Nearest to was: is, were, had, has, tl, when, relena, ruud,
# Nearest to th: migrant, billion, p, uke, budgets, rijndael, skirt, hakim,
# Nearest to first: at, handler, within, pseudo, city, implicated, pizzicato, antiprotons,
# Nearest to are: were, is, have, by, yoke, including, archons, other,
# Nearest to also: curator, acc, not, that, now, episkopos, however, asbestos,
# Nearest to an: the, imbued, piccard, perturbed, omnivores, gametes, alphabetically, brooms,
# Nearest to many: some, these, the, their, each, congratulate, off, its,
# Nearest to often: lost, system, starting, nilo, vieux, grimm, changeover, must,
